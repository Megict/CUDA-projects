# %%
import numpy as np
import pylab

# %%
# Out:
# {1, 2, 3}

# %%
times_100_50 = [587.494, 144.127, 132.075]
times_600_400 = [18842.3, 5021.07, 4175.11]
times_1200_900 = [74875.0, 42932.9, 34489.4]

# %%
pylab.plot([1,2,3],times_100_50,label = "20x100х50")
pylab.plot([1,2,3],times_600_400,label = "20x600х400")
pylab.plot([1,2,3],times_1200_900,label = "20x1200х900")
pylab.legend()
pylab.show()
